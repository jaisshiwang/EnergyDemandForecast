# %%
import pandas as pd

# %%
import os
print(os.path.exists('../data/time_series.csv'))
# Out:
# False

# %%
data_15_min = pd.read_excel('../data/time_series.xlsx', sheet_name='15min')
data_15_min.head()
# Out:
#   Unnamed: 0 Unnamed: 1                                                 AT  \
# 0        NaN        NaN                                               load
# 1        NaN        NaN                         actual_entsoe_transparency
# 2        NaN        NaN                               ENTSO-E Transparency
# 3        NaN        NaN  https://transparency.entsoe.eu/load-domain/r2/...
# 4        NaN        NaN                                                 MW
#
#                                                 AT.1  \
# 0                                               load
# 1                       forecast_entsoe_transparency
# 2                               ENTSO-E Transparency
# 3  https://transparency.entsoe.eu/load-domain/r2/...
# 4                                                 MW
#
#                                                 AT.2  \
# 0                                              price
# 1                                          day_ahead
# ...

# %%
columns = []
for i in range(len(data_15_min.columns)):
    if data_15_min.columns[i] == 'Unnamed: 0' :
        columns.append('utc_timestamp')
    elif data_15_min.columns[i] == 'Unnamed: 1' :
        columns.append('cet_cest_timestamp')
    else :
        columns.append(str(data_15_min.iloc[0,i]) + '_' + str(data_15_min.iloc[1,i]))

# %%
print(columns)
# Out:
# ['utc_timestamp', 'cet_cest_timestamp', 'load_actual_entsoe_transparency', 'load_forecast_entsoe_transparency', 'price_day_ahead', 'solar_generation_actual', 'wind_onshore_generation_actual', 'load_actual_entsoe_transparency', 'load_forecast_entsoe_transparency', 'load_actual_entsoe_transparency', 'load_forecast_entsoe_transparency', 'solar_capacity', 'solar_generation_actual', 'solar_profile', 'wind_capacity', 'wind_generation_actual', 'wind_profile', 'wind_offshore_capacity', 'wind_offshore_generation_actual', 'wind_offshore_profile', 'wind_onshore_capacity', 'wind_onshore_generation_actual', 'wind_onshore_profile', 'load_actual_entsoe_transparency', 'load_forecast_entsoe_transparency', 'solar_generation_actual', 'wind_generation_actual', 'wind_offshore_generation_actual', 'wind_onshore_generation_actual', 'load_actual_entsoe_transparency', 'load_forecast_entsoe_transparency', 'solar_generation_actual', 'wind_generation_actual', 'wind_offshore_generation_actual', 'wind_onshore_gene
# ...

# %%
data_15_min = data_15_min.loc[11:, :]
data_15_min.head()
# Out:
#              Unnamed: 0           Unnamed: 1      AT     AT.1   AT.2 AT.3  \
# 11  2015-01-01 00:15:00  2015-01-01 01:15:00  5966.8  6692.23  61.72  NaN
# 12  2015-01-01 00:30:00  2015-01-01 01:30:00  5935.6  6722.06     28  NaN
# 13  2015-01-01 00:45:00  2015-01-01 01:45:00  5934.4  6689.71  15.68  NaN
# 14  2015-01-01 01:00:00  2015-01-01 02:00:00  5750.8   6632.8  65.08  NaN
# 15  2015-01-01 01:15:00  2015-01-01 02:15:00  5777.6   6572.9  54.18  NaN
#
#      AT.4       BE      BE.1        DE  ... HU.2   HU.3   LU LU.1    NL  \
# 11  69.96  9575.73  10028.56  41517.72  ...  NaN  12.22  407  368  9524
# 12   69.8  9494.09   9877.94  41179.17  ...  NaN  13.27  401  360  9407
# 13  65.85   9382.5   9783.68   40756.4  ...  NaN  15.67  396  358  9271
# 14  62.23  9349.16   9675.46  40617.76  ...  NaN  15.35  392  350  9148
# 15  62.87  9213.16   9578.02  40312.25  ...  NaN   17.6  384  350  9025
#
#        NL.1 NL.2     NL.3    NL.4     NL.5
# 11  9081.49  NaN   1447.2  144.72  1302.48
# ...

# %%
data_15_min.columns = columns
data_15_min = data_15_min.reset_index(drop=True)
data_15_min.head()
# Out:
#          utc_timestamp   cet_cest_timestamp load_actual_entsoe_transparency  \
# 0  2015-01-01 00:15:00  2015-01-01 01:15:00                          5966.8
# 1  2015-01-01 00:30:00  2015-01-01 01:30:00                          5935.6
# 2  2015-01-01 00:45:00  2015-01-01 01:45:00                          5934.4
# 3  2015-01-01 01:00:00  2015-01-01 02:00:00                          5750.8
# 4  2015-01-01 01:15:00  2015-01-01 02:15:00                          5777.6
#
#   load_forecast_entsoe_transparency price_day_ahead solar_generation_actual  \
# 0                           6692.23           61.72                     NaN
# 1                           6722.06              28                     NaN
# 2                           6689.71           15.68                     NaN
# 3                            6632.8           65.08                     NaN
# 4                            6572.9           54.18                     NaN
#
# ...

# %%
data_15_min['utc_timestamp'] = pd.to_datetime(data_15_min['utc_timestamp'], format='%Y-%m-%d %H:%M:%S')
data_15_min.set_index('utc_timestamp', inplace=True)

# %%
print(data_15_min.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201599 entries, 0 to 201598
# Data columns (total 61 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   utc_timestamp                      201599 non-null  object
#  1   cet_cest_timestamp                 201599 non-null  object
#  2   load_actual_entsoe_transparency    201598 non-null  object
#  3   load_forecast_entsoe_transparency  201598 non-null  object
#  4   price_day_ahead                    131378 non-null  object
#  5   solar_generation_actual            201352 non-null  object
#  6   wind_onshore_generation_actual     201406 non-null  object
#  7   load_actual_entsoe_transparency    201598 non-null  object
#  8   load_forecast_entsoe_transparency  201502 non-null  object
#  9   load_actual_entsoe_transparency    201598 non-null  object
#  10  load_forecast_entsoe_transparency  201502 non-null  object
# ...
